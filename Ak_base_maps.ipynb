# %%
import leafmap.maplibregl as leafmap
import os
os.environ["MAPTILER_KEY"]="hAU2ZKHm5SFXNGFxBhtX"

# %%
m = leafmap.Map(center=[-1.0556313590281263,  6.151724296491395], zoom=13, style="streets")
#Adding icons as .png files 

source = {
    "type": "geojson",
    "data": {
        "type": "FeatureCollection",
        "features": [
            {
                "type": "Feature",
                "properties": {"id": "sch4001", "description": "Methodist Primary Sch.", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0562, 6.1534]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch1001", "description": "Presby Primary A", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.053976093402099, 6.149862560714496]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch1002", "description": "Presby Primary B", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0534, 6.1497]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch1003", "description": "Presby JHS ", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0536,  6.1488]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch1004", "description": "Presby Kingderteng", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0552, 6.1503]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch4004", "description": "Methodist JHS", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.05604, 6.1532]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch4003", "description": "Methodist Kingderteng", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0562528142090741, 6.1526389410362015]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch6001", "description": "St. Mary's Primary", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0462, 6.1521]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch6002", "description": "St. Mary's JHS", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0463, 6.1519]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch5001", "description": "Wisdom Primary","color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0670, 6.1492]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch5002", "description": "Wisdom JHS", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.0673, 6.1492]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2001", "description": "Akokoaso Senior High/Tech Sch(ArtBlock)", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058804,  6.148048]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch3002", "description": "Akokoaso DA  JHS", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058732,  6.14819]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2002", "description": "Akokoaso Senior High/Tech Sch(Business Block)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.059275,  6.147315]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2003", "description": "Akokoaso Senior High/Tech Sch(Technical Block)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.059551,  6.147163]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2004", "description": "Akokoaso Senior High/Tech Sch(Dinning hall)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.059648,   6.146765]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2005", "description": "Akokoaso Senior High/Tech Sch(Boys Dorm)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058981,  6.146827]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2008", "description": "Akokoaso Senior High/Tech Sch(Agric block)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [ -1.058683,  6.147315]},
            },
             {
                "type": "Feature",
                "properties": {"id": "sch3001", "description": "Akokoaso DA Primary School", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.057592,  6.147643]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2006", "description": "Akokoaso Senior High/Tech Sch(Home Econs Block)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058410,  6.147685]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2007", "description": "Akokoaso Senior High/Tech Sch(Girls Dorm.)", "color":"#071ebe","icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058303,  6.145871]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch2009", "description": "Akokoaso Senior High/Tech Sch(Masters Quaters)", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.058483,  6.144754]},
            },
            {
                "type": "Feature",
                "properties": {"id": "sch1006", "description": "Presby Teachers Quaters ", "color":"#071ebe", "icon":"school"},
                "geometry": {"type": "Point", "coordinates": [-1.053266,  6.149452]},
            },
            {
                    "type": "Feature",
                    "properties": {"id": "ch101", "description": "Presbyterian Church", "icon":"religious_christian"},
                    "geometry": {"type": "Point", "coordinates": [-1.0548306859647596,  6.150263304405513]},
                },
             {
                    "type": "Feature",
                    "properties": {"id": "ch102", "description": "Presby Mission House (Reverend Residence)", "icon":"religious_christian"},
                    "geometry": {"type": "Point", "coordinates": [-1.0551405703567411,  6.1500424828462315]},
                },
            {"type":"Feature",
             "properties":{"id":"ch201", "description":"Methodist church", "icon":"religious_christian"},
             "geometry":{"type":"Point", "coordinates":[-1.056158251962728, 6.152738577541726]},
            },
            {"type":"Feature",
             "properties":{"id":"ch201", "description":"Methodist Mission House(Reverend Residence)", "icon":"religious_christian"},
             "geometry":{"type":"Point", "coordinates":[-1.0562147850691872, 6.152956627515252]},
            },
           
        ],
    },
}
layer = {
    "id": "point",
    "type": "symbol",
    "source": "source",
    "layout": {
        "icon-image": ["concat", ["get", "icon"], "_11"],
        "icon-size": 1,
        "text-field": ["get", "description"],
        "text-font": ["Open Sans Regular"],
        "text-size":8,
        "text-offset": [0, 1],
        "text-anchor": "top",
    # "paint":["get", "color"],
        
    },
}
m.add_source("source", source)
m.add_layer(layer)

m
# Out:
# Map(height='600px', map_options={'bearing': 0, 'center': (-1.0556313590281263, 6.151724296491395), 'pitch': 0,…

# %%
import ipywidgets as widgets
output = widgets.Output()


def log_lng_lat(lng_lat):
    with output:
        output.clear_output()
        print(lng_lat.new)


m.observe(log_lng_lat, names="clicked")
output
# Out:
# Output()
